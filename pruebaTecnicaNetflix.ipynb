# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandezzz/Pruebas_Tecnicas/blob/main/pruebaTecnicaNetflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **¿Cual es la pelicula que mas dura en Netflix?**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13         90
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# Nuevo DataFrame solo con las peliculas

# %%
df_movies = df[df['type'] == 'Movie']
df_movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
#mask = df['type'] == 'Movie'
#df_movies = df[mask]
#df_movies.head()

# %%
df_movies.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# Existencia de valores nulos en la columna 'duration'

# %%
null_values = df['duration'].isna().sum()
null_values
# Out:
# np.int64(3)

# %% [markdown]
# Se visualiza las filas que contienen valor nulo en la columna 'duration'

# %%
mask_null = df_movies['duration'].isna()
df_movies[mask_null]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
# mask = df_movies['duration'].isna()
# df_movies.loc[mask, 'duration'] = df_movies.loc[mask, 'duration'].fillna('0')

# %% [markdown]
# Lista que almacena las duraciones de las peliculas

# %%
duracion_peliculas = df_movies['duration'].to_list()
len(duracion_peliculas)
# Out:
# 6131

# %% [markdown]
# Funcion para iterar sobre la lista, transformar cada string a numero decimal y devolver el valor numerico mas alto

# %%
def maxima_duracion(lista):
  duration = [float(d) for d in lista]
  return max(duration)

f'La duracion maxima de una pelicula en el DataFrame es de {maxima_duracion(duracion_peliculas)} minutos.'
# Out:
# 'La duracion maxima de una pelicula en el DataFrame es de 273.0 minutos.'

# %% [markdown]
# Obtener los datos de la pelicula cuya duracion es la obtenida previamente

# %%
mask = df_movies['duration'] == '273'
longest_movie = df_movies[mask]
longest_movie[['type', 'title', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']]
# Out:
#       type                        title     date_added  release_year rating  \
# 717  Movie  Headspace: Unwind Your Mind  June 15, 2021          2021   TV-G
#
#     duration      listed_in                                        description
# 717      273  Documentaries  Do you want to relax, meditate or sleep deeply...

# %% [markdown]
# Otra solucion

# %%
df_moviess = df[df['type'] == 'Movie'][['title', 'duration']]
df_moviess.head()
# Out:
#                                title duration
# 0               Dick Johnson Is Dead       90
# 6   My Little Pony: A New Generation       91
# 7                            Sankofa      125
# 9                       The Starling      104
# 12                      Je Suis Karl      127

# %%
id_longest_movie = df_moviess['duration'].fillna('0')
id_longest_movie.astype(int).idxmax()
# Out:
# np.int64(717)

# %%
longest_movie = df.loc[id_longest_movie.astype(int).idxmax()]
longest_movie[['type', 'title', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']]
# Out:
# type                                                        Movie
# title                                 Headspace: Unwind Your Mind
# date_added                                          June 15, 2021
# release_year                                                 2021
# rating                                                       TV-G
# duration                                                      273
# listed_in                                           Documentaries
# description     Do you want to relax, meditate or sleep deeply...
# Name: 717, dtype: object

# %% [markdown]
# **¿En que año se subieron (date_added) mas peliculas a Netflix?**

# %%
df_movies.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_movies.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_movies['date_added'].value_counts()
# Out:
# date_added
# January 1, 2020      97
# November 1, 2019     75
# March 1, 2018        72
# December 31, 2019    67
# October 1, 2018      64
#                      ..
# June 23, 2019         1
# December 23, 2018     1
# October 26, 2019      1
# April 21, 2019        1
# May 26, 2016          1
# Name: count, Length: 1533, dtype: int64

# %% [markdown]
# Se comprueba la existencia de valores nulos

# %%
df_movies['date_added'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Buscar la cantidad de peliculas que se subieron a Netflix por año

# %%
mask2021 = df_movies['date_added'].str.contains('2021')
df_2021 = df_movies[mask2021]
df_2021.shape[0]
# Out:
# 993

# %%
mask2020 = df_movies['date_added'].str.contains('2020')
df_2020 = df_movies[mask2020]
df_2020.shape[0]
# Out:
# 1284

# %% [markdown]
# 2019 es el año con mas cantidad de peliculas subidas a la plataforma Netflix

# %%
mask2019 = df_movies['date_added'].str.contains('2019')
df_2019 = df_movies[mask2019]
df_2019.shape[0]
# Out:
# 1424

# %%
mask2018 = df_movies['date_added'].str.contains('2018')
df_2018 = df_movies[mask2018]
df_2018.shape[0]
# Out:
# 1237

# %%
mask2017 = df_movies['date_added'].str.contains('2017')
df_2017 = df_movies[mask2017]
df_2017.shape[0]
# Out:
# 839

# %%
mask2016 = df_movies['date_added'].str.contains('2016')
df_2016 = df_movies[mask2016]
df_2016.shape[0]
# Out:
# 253

# %%
mask2015 = df_movies['date_added'].str.contains('2015')
df_2015 = df_movies[mask2015]
df_2015.shape[0]
# Out:
# 56

# %%
mask2014 = df_movies['date_added'].str.contains('2014')
df_2014 = df_movies[mask2014]
df_2014.shape[0]
# Out:
# 19

# %%
mask2013 = df_movies['date_added'].str.contains('2013')
df_2013 = df_movies[mask2013]
df_2013.shape[0]
# Out:
# 6

# %%
mask2012 = df_movies['date_added'].str.contains('2012')
df_2012 = df_movies[mask2012]
df_2012.shape[0]
# Out:
# 3

# %%
mask2011 = df_movies['date_added'].str.contains('2011')
df_2011 = df_movies[mask2011]
df_2011.shape[0]
# Out:
# 13

# %%
mask2010 = df_movies['date_added'].str.contains('2010')
df_2010 = df_movies[mask2010]
df_2010.shape[0]
# Out:
# 1

# %%
mask2009 = df_movies['date_added'].str.contains('2009')
df_2009 = df_movies[mask2009]
df_2009.shape[0]
# Out:
# 2

# %%
mask2008 = df_movies['date_added'].str.contains('2008')
df_2008 = df_movies[mask2008]
df_2008.shape[0]
# Out:
# 1

# %% [markdown]
# **¿En que año se estrenaron (release_year) mas peliculas?**

# %%
conteo_peliculas = df_movies['release_year'].value_counts().head()
conteo_peliculas
# Out:
# release_year
# 2017    767
# 2018    767
# 2016    658
# 2019    633
# 2020    517
# Name: count, dtype: int64

# %%
conteo_peliculas.idxmax()
# Out:
# np.int64(2017)

# %%
conteo_peliculas.max()
# Out:
# 767

# %%
f'El año en el que mas se estrenaron peliculas fue {conteo_peliculas.idxmax()} y la cantidad de peliculas estrenadas ese año fue {conteo_peliculas.max()}'
# Out:
# 'El año en el que mas se estrenaron peliculas fue 2017 y la cantidad de peliculas estrenadas ese año fue 767'

# %%
year_percentage_movies = pd.DataFrame(df_movies['release_year'].value_counts())
year_percentage_movies.rename(columns={'count': 'films'}, inplace=True)
year_percentage_movies['%'] = round(year_percentage_movies['films'] / year_percentage_movies['films'].sum() * 100, 2)
year_percentage_movies.head()
# Out:
#               films      %
# release_year
# 2017            767  12.51
# 2018            767  12.51
# 2016            658  10.73
# 2019            633  10.32
# 2020            517   8.43

# %% [markdown]
# **¿Que pais produce mas series de Netflix?**

# %% [markdown]
# Filtrar por TV Show

# %%
mask = df['type'] == 'TV Show'
df_series = df[mask]
df_series.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df_series.shape[0]
# Out:
# 2676

# %% [markdown]
# Se verifica la existencia de valores nulos en la columna 'country'

# %%
df_series['country'].isna().sum()
# Out:
# np.int64(391)

# %% [markdown]
# Calcular el porcentaje de valores nulos en la columna 'country' con respecto a la totalidad de las columnas

# %%
porcentaje_nulos = round(df_series['country'].isna().sum() / df_series.shape[0] * 100, 2)
f'El porcentaje de valores nulos en la columna Country para las Series es {porcentaje_nulos}%'
# Out:
# 'El porcentaje de valores nulos en la columna Country para las Series es 14.61%'

# %% [markdown]
# Sustituir los valores nulos con el string 'No especificado'

# %%
df_series['country'] = df_series['country'].fillna('No especificado')
df_series.head()
# Out:
# /tmp/ipykernel_3001/218567655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_series['country'] = df_series['country'].fillna('No especificado')
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast          country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  No especificado
# ...

# %%
f'El pais que produce mas Series para Netflix es: {df_series['country'].value_counts().idxmax()}'
# Out:
# 'El pais que produce mas Series para Netflix es: United States'

# %%
series_country_percentage = pd.DataFrame(df_series['country'].value_counts())
series_country_percentage.rename(columns={'count': 'Series'}, inplace=True)
series_country_percentage['%'] = round(series_country_percentage['Series'] / series_country_percentage['Series'].sum() * 100, 2)
series_country_percentage.head(1)
# Out:
#                Series     %
# country
# United States     760  28.4

# %% [markdown]
# **¿Cual es la duracion media de las peliculas por decada en Netflix?**

# %%
df_movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
df_movies.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_movies['duration'] = df_movies['duration'].astype(float)
df_movies.head()
# Out:
# /tmp/ipykernel_3001/777645573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['duration'] = df_movies['duration'].astype(float)
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
# ...

# %%
df_movies.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration        float64
# listed_in        object
# description      object
# dtype: object

# %% [markdown]
# Nueva columna con el valor de la decada correspondiente a cada año

# %%
df_movies['decade'] = (df_movies['release_year'] // 10) * 10 # // division entera
df_movies.head()
# Out:
# /tmp/ipykernel_3001/3081884122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['decade'] = (df_movies['release_year'] // 10) * 10 # // division entera
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
# ...

# %% [markdown]
# Agrupar por decada y duracion promedio de peliculas por decada

# %%
duration = round(df_movies.groupby('decade')['duration'].mean(), 2) # .idxmax()
duration
# Out:
# decade
# 1940     51.38
# 1950    107.09
# 1960    147.61
# 1970    119.24
# 1980    116.23
# 1990    113.84
# 2000    112.11
# 2010     96.87
# 2020     93.64
# Name: duration, dtype: float64
