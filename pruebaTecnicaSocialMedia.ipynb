# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandezzz/Pruebas_Tecnicas/blob/main/pruebaTecnicaSocialMedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **¿Con que edad se consumen mas las redes sociales?**

# %% [markdown]
# Obtener el promedio de edad y de cantidad de horas de uso de las redes sociales. Tomar como referencia los valores de la columna Daily_Screen_Time_Hours y la columna edad.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/social_media_mental_health.csv')
df.head(10)
# Out:
#       User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 0  U-b23639d2   18    Male     Hyper-Connected        Twitter/X
# 1  U-e7778765   20    Male  Digital Minimalist           TikTok
# 2  U-76749892   18  Female  Digital Minimalist         Snapchat
# 3  U-dcbbd7f9   18  Female     Hyper-Connected         Snapchat
# 4  U-9e1ba278   18    Male     Hyper-Connected         LinkedIn
# 5  U-e578c94a   18    Male  Digital Minimalist          YouTube
# 6  U-a04da6a8   20  Female     Hyper-Connected         Facebook
# 7  U-408fc499   18  Female     Hyper-Connected        Twitter/X
# 8  U-90ce461c   18    Male    Passive Scroller         Facebook
# 9  U-ee0c9c9b   20    Male        Average User         LinkedIn
#
#    Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 0                     8.50                Gaming        Active
# 1                     0.50                Gaming        Active
# 2                     0.91                Gaming        Active
# ...

# %%
df.shape[0]
# Out:
# 8000

# %%
df['User_ID'].duplicated().value_counts()
# Out:
# User_ID
# False    8000
# Name: count, dtype: int64

# %%
#se agrupa por edad y se calcula el tiempo de consumo diario
result = df.groupby('Age')['Daily_Screen_Time_Hours'].mean()
result
# Out:
# Age
# 18    4.251766
# 19    4.301255
# 20    4.296683
# 21    4.129801
# 22    4.401807
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
#se obtiene la edad con mayor promedio de horas
result.idxmax()
# Out:
# np.int64(22)

# %%
#se obtiene el mayor promedio de horas
round(result.max(), 1)
# Out:
# 4.4

# %%
f'La edad en la que se consumen mas redes sociales es {result.idxmax()} años y el promedio de horas diario es de {round(result.max(), 1)} horas'
# Out:
# 'La edad en la que se consumen mas redes sociales es 22 años y el promedio de horas diario es de 4.4 horas'

# %%
df['Primary_Platform'].value_counts()
# Out:
# Primary_Platform
# TikTok       1185
# Instagram    1165
# Twitter/X    1147
# YouTube      1134
# LinkedIn     1132
# Snapchat     1124
# Facebook     1113
# Name: count, dtype: int64

# %%
df['Primary_Platform'].unique()
# Out:
# array(['Twitter/X', 'TikTok', 'Snapchat', 'LinkedIn', 'YouTube',
#        'Facebook', 'Instagram'], dtype=object)

# %%
mask = df['Primary_Platform'] == 'Twitter/X'
df_twitter = df[mask]
df_twitter.head(10)
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 0   U-b23639d2   18    Male     Hyper-Connected        Twitter/X
# 7   U-408fc499   18  Female     Hyper-Connected        Twitter/X
# 10  U-52f7cdb6   18  Female     Hyper-Connected        Twitter/X
# 29  U-7dd33870   20  Female     Hyper-Connected        Twitter/X
# 69  U-eb7eb16f   18    Male  Digital Minimalist        Twitter/X
# 71  U-93b0a456   18  Female        Average User        Twitter/X
# 77  U-2e1f658c   18    Male     Hyper-Connected        Twitter/X
# 85  U-33cae531   19    Male     Hyper-Connected        Twitter/X
# 89  U-003fc6a5   21    Male  Digital Minimalist        Twitter/X
# 91  U-ed3b68ad   21  Female  Digital Minimalist        Twitter/X
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 0                      8.50                Gaming        Active
# 7                      7.18     Lifestyle/Fashion        Active
# ...

# %%
tw_data = df_twitter.groupby('Age')['Daily_Screen_Time_Hours'].mean()
tw_data
# Out:
# Age
# 18    4.363414
# 19    4.202046
# 20    4.287049
# 21    4.196226
# 22    4.654898
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
tw_data.idxmax()
# Out:
# np.int64(22)

# %%
round(tw_data.max(), 1)
# Out:
# 4.7

# %%
mask = df['Primary_Platform'] == 'TikTok'
df_tiktok = df[mask]
df_tiktok.head(10)
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 1   U-e7778765   20    Male  Digital Minimalist           TikTok
# 38  U-1ae8dde4   20  Female        Average User           TikTok
# 43  U-39fe18d8   18  Female        Average User           TikTok
# 49  U-a8b4462b   18    Male        Average User           TikTok
# 57  U-2b1c4ae4   18    Male  Digital Minimalist           TikTok
# 61  U-7f0e85b9   19    Male     Hyper-Connected           TikTok
# 65  U-4a51aad2   18    Male     Hyper-Connected           TikTok
# 66  U-4c977481   18    Male        Average User           TikTok
# 74  U-c11aa96e   19    Male    Passive Scroller           TikTok
# 82  U-db5d5671   22  Female    Passive Scroller           TikTok
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 1                      0.50                Gaming        Active
# 38                     4.27      Educational/Tech        Active
# ...

# %%
data_tiktok = df_tiktok.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_tiktok
# Out:
# Age
# 18    4.104775
# 19    4.425470
# 20    4.322026
# 21    3.988000
# 22    4.836563
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_tiktok.idxmax()
# Out:
# np.int64(22)

# %%
round(data_tiktok.max(), 1)
# Out:
# 4.8

# %%
mask = df['Primary_Platform'] == 'Snapchat'
df_snapchat = df[mask]
df_snapchat.head(10)
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 2   U-76749892   18  Female  Digital Minimalist         Snapchat
# 3   U-dcbbd7f9   18  Female     Hyper-Connected         Snapchat
# 16  U-b009c953   21  Female  Digital Minimalist         Snapchat
# 18  U-8a4ed12e   21    Male        Average User         Snapchat
# 25  U-689a3f70   18  Female    Passive Scroller         Snapchat
# 26  U-a4bbe796   19  Female        Average User         Snapchat
# 28  U-b5fbc85f   22  Female  Digital Minimalist         Snapchat
# 31  U-99f5e822   19  Female    Passive Scroller         Snapchat
# 32  U-bec1773d   19    Male        Average User         Snapchat
# 41  U-912b139e   18    Male        Average User         Snapchat
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 2                      0.91                Gaming        Active
# 3                      7.43                Gaming        Active
# ...

# %%
data_snapchat = df_snapchat.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_snapchat
# Out:
# Age
# 18    4.305145
# 19    4.487126
# 20    4.324215
# 21    3.659000
# 22    3.836226
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_snapchat.idxmax()
# Out:
# np.int64(19)

# %%
round(data_snapchat.max(), 1)
# Out:
# 4.5

# %%
mask = df['Primary_Platform'] == 'LinkedIn'
df_linkedin = df[mask]
df_linkedin.head()
# Out:
#        User_ID  Age  Gender    User_Archetype Primary_Platform  \
# 4   U-9e1ba278   18    Male   Hyper-Connected         LinkedIn
# 9   U-ee0c9c9b   20    Male      Average User         LinkedIn
# 13  U-605ccf37   21  Female  Passive Scroller         LinkedIn
# 17  U-12db71e9   20  Female  Passive Scroller         LinkedIn
# 40  U-1d8214eb   18    Male   Hyper-Connected         LinkedIn
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 4                      4.94  Entertainment/Comedy        Active
# 9                      1.97                Gaming        Active
# 13                     5.17                Gaming       Passive
# 17                     6.30                Gaming       Passive
# 40                     9.35         News/Politics        Active
#
#     Late_Night_Usage  Social_Comparison_Trigger  Sleep_Duration_Hours  \
# 4                  1                          0                   5.3
# ...

# %%
data_linkedin = df_linkedin.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_linkedin
# Out:
# Age
# 18    4.214746
# 19    4.340536
# 20    4.170995
# 21    4.171228
# 22    4.307692
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_linkedin.idxmax()
# Out:
# np.int64(19)

# %%
round(data_linkedin.max(), 1)
# Out:
# 4.3

# %%
mask = df['Primary_Platform'] == 'YouTube'
df_youtube = df[mask]
df_youtube.head()
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 5   U-e578c94a   18    Male  Digital Minimalist          YouTube
# 12  U-4a6926f5   20  Female  Digital Minimalist          YouTube
# 14  U-71a32e79   18    Male        Average User          YouTube
# 15  U-02e9f400   18  Female  Digital Minimalist          YouTube
# 21  U-e51d3cef   20    Male     Hyper-Connected          YouTube
# 30  U-22299b7f   18  Female  Digital Minimalist          YouTube
# 33  U-dcb3dfef   21  Female        Average User          YouTube
# 35  U-eb0bd6d4   19  Female     Hyper-Connected          YouTube
# 37  U-2c4215a2   19  Female        Average User          YouTube
# 46  U-813198e7   19    Male        Average User          YouTube
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 5                      0.56  Entertainment/Comedy        Active
# 12                     1.19  Entertainment/Comedy        Active
# ...

# %%
data_youtube = df_youtube.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_youtube
# Out:
# Age
# 18    4.308956
# 19    4.173740
# 20    4.199220
# 21    4.526034
# 22    3.961500
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_youtube.idxmax()
# Out:
# np.int64(21)

# %%
round(data_youtube.max(), 1)
# Out:
# 4.5

# %%
mask = df['Primary_Platform'] == 'Facebook'
df_facebook = df[mask]
df_facebook.head()
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 6   U-a04da6a8   20  Female     Hyper-Connected         Facebook
# 8   U-90ce461c   18    Male    Passive Scroller         Facebook
# 19  U-1835eda3   19    Male        Average User         Facebook
# 20  U-e57dec90   19    Male     Hyper-Connected         Facebook
# 22  U-0a35b86b   20    Male     Hyper-Connected         Facebook
# 23  U-9654a249   22  Female        Average User         Facebook
# 24  U-09312822   21  Female    Passive Scroller         Facebook
# 34  U-c61daa8d   19  Female        Average User         Facebook
# 42  U-c35a8797   19  Female        Average User         Facebook
# 44  U-9da1342f   22  Female  Digital Minimalist         Facebook
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 6                      6.57     Lifestyle/Fashion        Active
# 8                      3.41     Lifestyle/Fashion       Passive
# ...

# %%
data_facebook = df_facebook.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_facebook
# Out:
# Age
# 18    4.284247
# 19    4.269598
# 20    4.476111
# 21    3.980161
# 22    4.099687
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_facebook.idxmax()
# Out:
# np.int64(20)

# %%
round(data_facebook.max(), 1)
# Out:
# 4.5

# %%
mask = df['Primary_Platform'] == 'Instagram'
df_instagram = df[mask]
df_instagram.head()
# Out:
#        User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 11  U-5a564189   20  Female        Average User        Instagram
# 27  U-dd5e1f35   20    Male  Digital Minimalist        Instagram
# 36  U-7bdd5fe1   18  Female  Digital Minimalist        Instagram
# 39  U-def4effe   19    Male  Digital Minimalist        Instagram
# 48  U-336e87ee   18  Female        Average User        Instagram
# 54  U-3af5d1d9   19    Male     Hyper-Connected        Instagram
# 78  U-fd1879e8   19    Male        Average User        Instagram
# 81  U-b0e0ab59   19    Male     Hyper-Connected        Instagram
# 86  U-6621829d   18  Female    Passive Scroller        Instagram
# 88  U-e18aa451   20  Female     Hyper-Connected        Instagram
#
#     Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 11                     4.18  Self-Help/Motivation        Active
# 27                     0.80         News/Politics        Active
# ...

# %%
data_instagram = df_instagram.groupby('Age')['Daily_Screen_Time_Hours'].mean()
data_instagram
# Out:
# Age
# 18    4.194571
# 19    4.207281
# 20    4.281339
# 21    4.460000
# 22    5.251224
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
data_instagram.idxmax()
# Out:
# np.int64(22)

# %%
round(data_instagram.max(), 1)
# Out:
# 5.3

# %% [markdown]
# **¿Cuantas horas consume un usuario al dia de redes sociales?**

# %%
df.head()
# Out:
#       User_ID  Age  Gender      User_Archetype Primary_Platform  \
# 0  U-b23639d2   18    Male     Hyper-Connected        Twitter/X
# 1  U-e7778765   20    Male  Digital Minimalist           TikTok
# 2  U-76749892   18  Female  Digital Minimalist         Snapchat
# 3  U-dcbbd7f9   18  Female     Hyper-Connected         Snapchat
# 4  U-9e1ba278   18    Male     Hyper-Connected         LinkedIn
#
#    Daily_Screen_Time_Hours Dominant_Content_Type Activity_Type  \
# 0                     8.50                Gaming        Active
# 1                     0.50                Gaming        Active
# 2                     0.91                Gaming        Active
# 3                     7.43                Gaming        Active
# 4                     4.94  Entertainment/Comedy        Active
#
#    Late_Night_Usage  Social_Comparison_Trigger  Sleep_Duration_Hours  \
# 0                 0                          0                   3.9
# ...

# %%
df.dtypes
# Out:
# User_ID                       object
# Age                            int64
# Gender                        object
# User_Archetype                object
# Primary_Platform              object
# Daily_Screen_Time_Hours      float64
# Dominant_Content_Type         object
# Activity_Type                 object
# Late_Night_Usage               int64
# Social_Comparison_Trigger      int64
# Sleep_Duration_Hours         float64
# GAD_7_Score                    int64
# GAD_7_Severity                object
# PHQ_9_Score                    int64
# PHQ_9_Severity                object
# dtype: object

# %% [markdown]
# Cantidad de horas promedio que los usuarios utilizan las redes sociales por dia

# %%
avg_hours_user = df['Daily_Screen_Time_Hours'].mean()
round(avg_hours_user, 2)
# Out:
# np.float64(4.28)

# %% [markdown]
# Obtener la cantidad de horas promedio que los usuarios utilizan TikTok

# %%
tiktok_hours = df['Daily_Screen_Time_Hours'][df['Primary_Platform'] == 'TikTok'].mean()
round(tiktok_hours, 2)
# Out:
# np.float64(4.28)

# %% [markdown]
# Obtener una tabla con las redes sociales y la cantidad de horas diarias promedio de uso para cada una de ellas

# %%
social_hours = df.groupby('Primary_Platform')['Daily_Screen_Time_Hours'].mean()
round(social_hours, 2)
# Out:
# Primary_Platform
# Facebook     4.29
# Instagram    4.27
# LinkedIn     4.25
# Snapchat     4.31
# TikTok       4.28
# Twitter/X    4.30
# YouTube      4.24
# Name: Daily_Screen_Time_Hours, dtype: float64
